# %% [markdown]
# <a href="https://colab.research.google.com/github/Renalderek/Aplikasi-LOGI/blob/main/latihan_konversi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('sample_data/tingkat-kegemaran-membaca-tgm-2021.csv')
df.head()
# Out:
#     No        Provinsi  Kode Wilayah Provinsi  Latitude  Longtitude  \
# 0  1.0            Aceh                   11.0       4.0        97.0
# 1  2.0  Sumatera Utara                   12.0       2.0        99.0
# 2  3.0  Sumatera Barat                   13.0      -1.0       100.0
# 3  4.0            Riau                   14.0       1.0       102.0
# 4  5.0           Jambi                   15.0      -2.0       103.0
#
#    Frekuensi Membaca  Jumlah Bahan Bacaan Durasi Membaca (Jam/Hari)  \
# 0  5 - 6 kali/minggu  4 - 5 buku/triwulan            1 jam 43 menit
# 1  4 - 5 kali/minggu      4 buku/triwulan          1 jam 34.1 menit
# 2      5 kali/minggu  4 - 5 buku/triwulan            1 jam 28 menit
# 3      5 kali/minggu      4 buku/triwulan          1 jam 30.6 menit
# 4  4 - 5 kali/minggu      4 buku/triwulan          1 jam 28.6 menit
#
#   Frekuensi Akses Internet Durasi Akses Internet (Jam/Hari)  \
# 0            5 kali/minggu                 1 jam 23.9 menit
# ...
